# %%
import csv

# %%
with open("fishdata.csv", 'r') as fish:
    read = csv.DictReader(fish, delimiter = ',')
    for row in read:
        if row['family'] == 'Labridae':
            print(row)
# Out:
# OrderedDict([('species', 'Acantholabrus_palloni'), ('family', 'Labridae'), ('order', 'Perciformes'), ('length', '25'), ('length.measurement', 'TL')])
# OrderedDict([('species', 'Achoerodus_viridis'), ('family', 'Labridae'), ('order', 'Perciformes'), ('length', '62'), ('length.measurement', 'TL')])
# OrderedDict([('species', 'Anampses_caeruleopunctatus'), ('family', 'Labridae'), ('order', 'Perciformes'), ('length', '42'), ('length.measurement', 'TL')])
# OrderedDict([('species', 'Anampses_geographicus'), ('family', 'Labridae'), ('order', 'Perciformes'), ('length', '31'), ('length.measurement', 'TL')])
# OrderedDict([('species', 'Anampses_meleagrides'), ('family', 'Labridae'), ('order', 'Perciformes'), ('length', '22'), ('length.measurement', 'TL')])
# OrderedDict([('species', 'Anampses_neoguinaicus'), ('family', 'Labridae'), ('order', 'Perciformes'), ('length', '20'), ('length.measurement', 'SL')])
# ...

# %%
# avglength={}
with open('fishdata.csv', 'r') as fish:
    read = csv.DictReader(fish, delimiter = ',')
    for row in read:
        if row['family'] not in avglength:
            avglength[row['family']] = list()
        elif row['length'] == 'NA':
            continue
        else:
            avglength[row['family']].append(float(row['length']))
    
for key in avglength:
    total=(sum(avglength[key]))
    length=(len(avglength[key]))
    print(length)
# Out:
# 2756
# 77
# 11
# 86
# 639
# 515
# 29
# 50
# 92
# 14
# 254
# 554
# 6
# 224
# 122
# 113
# 539
# 221
# 44
# 266
# 17
# 143
# 1538
# 17
# 74
# 20
# 68
# 299
# 11
# 29
# 98
# 18
# 5
# 2
# 89
# 20
# 53
# 71
# 62
# 8
# 104
# 32
# 23
# 191
# 8
# 248
# 41
# 8
# 8
# 95
# 374
# 20
# 17
# 101
# 20
# 56
# 170
# 20
# 33
# 23
# 116
# 2
# 287
# 452
# 11
# 164
# 281
# 17
# 59
# 41
# 11
# 8
# 149
# 71
# 35
# 48
# 152
# 5
# 2
# 2
# 20
# 2
# 23
# 5
# 44
# 20
# 158
# 23
# 143
# 2
# 173
# 299
# 35
# 0
# 17
# 101
# 11
# 218
# 14
# 65
# 128
# 14
# 20
# 2
# 59
# 5
# 11
# 32
# 11
# 41
# 104
# 146
# 50
# 8
# 8
# 263
# 401
# 44
# 5
# 0
# 2
# 5
# 95
# 23
# 155
# 20
# 41
# 5
# 6
# 5
# 11
# 143
# 5
# 53
# 56
# 2
# 2
# 95
# 26
# 14
# 8
# 2
# 20
# 32
# 26
# 80
# 182
# 2
# 2
# 5
# 110
# 5
# 20
# 14
# 161
# 29
# 47
# 131
# 155
# 6
# 11
# 155
# 47
# 27
# 20
# 32
# 2
# 20
# 11
# 35
# 8
# 5
# 23
# 110
# 2
# 17
# 2
# 5
# 68
# 0
# 14
# 143
# 11
# 5
# 2
# 29
# 35
# 2
# 26
# 15
# 5
# 0
# 38
# 11
# 5
# 44
# 2
# 8
# 5
# 65
# ...

# %% [markdown]
# # Write a function that will take a string and return the statement "This string has X characters"

# %%
mystring = 'A chick has just so much time to chip its way out'

# %%
mylist = ['2', 2, 'two']

# %%
def lengthcounter(ss):
    sl = len(ss)
    print('This string has {} characters.'.format(sl))

# %%
lengthcounter(mylist)
# Out:
# This string has 3 characters.

# %%
lengthcounter(mystring)
# Out:
# This string has 49 characters.

# %%
lengthcounter('cat')
# Out:
# This string has 3 characters.
